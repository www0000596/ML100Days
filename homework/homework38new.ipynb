# %%
# import library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics
import seaborn as sns
from IPython.display import display

# %%
df = pd.read_csv("Titanic_train.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_1=df.copy() #複製一份資料給 data
from sklearn import preprocessing
# 裡面不能有int的形式，都必須是浮點數
le = preprocessing.LabelEncoder()
df_1['Sex']=le.fit_transform(df_1['Sex']) # male = 1, female = 0
display(df_1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
# step1: 觀察 Age 和 Pclass 與 Sex 是否有關連性?
g1 = sns.regplot(x="Age", y="Pclass", color="g",data=df)

# %%
g2 = sns.regplot(x="Age", y="Sex", color="g",data=df_1)

# %%
g3 = sns.regplot(x="Pclass", y="Sex", color="g",data=df_1)

# %%
# step2: 如果有關連性，運用 KNN ，取出 Age 、 Pclass、 Sex的資料，以 Sex 與 Pclass 補 Age 遺失值。
df_1.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df_new = df_1[['Age','Pclass','Sex']]
df_new
# Out:
#       Age  Pclass  Sex
# 0    22.0       3    1
# 1    38.0       1    0
# 2    26.0       3    0
# 3    35.0       1    0
# 4    35.0       3    1
# ..    ...     ...  ...
# 886  27.0       2    1
# 887  19.0       1    0
# 888   NaN       3    0
# 889  26.0       1    1
# 890  32.0       3    1
#
# [891 rows x 3 columns]

# %%
# 進行補值，取所有資料集結後最相近的一筆
value_neighbors=1
from sklearn.impute import KNNImputer
# 先設定要娶幾個鄰近點，如果是1就不需要取權重
imputer = KNNImputer(n_neighbors=value_neighbors)
df_filled = pd.DataFrame(imputer.fit_transform(df_new))
df_filled
# Out:
#         0    1    2
# 0    22.0  3.0  1.0
# 1    38.0  1.0  0.0
# 2    26.0  3.0  0.0
# 3    35.0  1.0  0.0
# 4    35.0  3.0  1.0
# ..    ...  ...  ...
# 886  27.0  2.0  1.0
# 887  19.0  1.0  0.0
# 888  26.0  3.0  0.0
# 889  26.0  1.0  1.0
# 890  32.0  3.0  1.0
#
# [891 rows x 3 columns]
