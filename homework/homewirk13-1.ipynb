# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame({
    'fruit': ['apple', 'banana', 'orange'] * 3,
    'weight': ['high', 'medium', 'low'] * 3,
    'price': np.random.randint(0, 15, 9)
})

df2 = pd.DataFrame({
    'fruit': ['apple', 'orange', 'pine'] * 2,
    'weight': ['high', 'low'] * 3,
    'price': np.random.randint(0, 15, 6)
})
print(df1)
print(df2)
# Out:
#     fruit  weight  price
# 0   apple    high     12
# 1  banana  medium      1
# 2  orange     low      5
# 3   apple    high     13
# 4  banana  medium      2
# 5  orange     low      7
# 6   apple    high      2
# 7  banana  medium     10
# 8  orange     low      3
#     fruit weight  price
# 0   apple   high     14
# 1  orange    low      4
# 2    pine   high      5
# 3   apple    low     13
# 4  orange   high      6
# 5    pine    low     10

# %%
# - 依照 fruit 欄位做合併
pd.merge(df1,df2,on = 'fruit')
# Out:
#      fruit weight_x  price_x weight_y  price_y
# 0    apple     high       12     high       14
# 1    apple     high       12      low       13
# 2    apple     high       13     high       14
# 3    apple     high       13      low       13
# 4    apple     high        2     high       14
# 5    apple     high        2      low       13
# 6   orange      low        5      low        4
# 7   orange      low        5     high        6
# 8   orange      low        7      low        4
# 9   orange      low        7     high        6
# 10  orange      low        3      low        4
# 11  orange      low        3     high        6

# %%
# - 依照 index 索引做合併
df1.join(df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-43ebfb56e105> in <module>
#       1 # - 依照 index 索引做合併
# ----> 2 df1.join(df2)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7868         5  K5  A5  NaN
#    7869         """
# -> 7870         return self._join_compat(
#    7871             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7872         )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7884
#    7885         if isinstance(other, DataFrame):
# -> 7886             return merge(
#    7887                 self,
#    7888                 other,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     668         join_index, left_indexer, right_indexer = self._get_join_info()
#     669
# --> 670         llabels, rlabels = _items_overlap_with_suffix(
#     671             self.left._info_axis, self.right._info_axis, self.suffixes
#     672         )
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2089
#    2090     if not lsuffix and not rsuffix:
# -> 2091         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2092
#    2093     def renamer(x, suffix):
#
# ValueError: columns overlap but no suffix specified: Index(['fruit', 'weight', 'price'], dtype='object')

# %%
# 2. [簡答題] 承上題，請問為什麼依照 merge 合併後有些資料不見了？
# 因為兩個資料表的列述必須相同才能進行合併

# %%
# 3. [簡答題] 承上題，請問為什麼依照 index 合併會發生錯誤？請用程式解決。
# 因為欄位不同不能正確合併
pd.merge(df1,df2)
# Out:
# Empty DataFrame
# Columns: [fruit, weight, price]
# Index: []

# %%
df1.join(df2, lsuffix='_df1', rsuffix='_df2')
# Out:
#   fruit_df1 weight_df1  price_df1 fruit_df2 weight_df2  price_df2
# 0     apple       high         12     apple       high       14.0
# 1    banana     medium          1    orange        low        4.0
# 2    orange        low          5      pine       high        5.0
# 3     apple       high         13     apple        low       13.0
# 4    banana     medium          2    orange       high        6.0
# 5    orange        low          7      pine        low       10.0
# 6     apple       high          2       NaN        NaN        NaN
# 7    banana     medium         10       NaN        NaN        NaN
# 8    orange        low          3       NaN        NaN        NaN
